# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import json
import os

# %%
with open("downloadlist_json.json",'r') as handler:
  downloadlist=json.load(handler)

# %%
type(downloadlist)
# Out:
# list

# %%
faileddownload=[]
trying_index=0
for i,k in enumerate(downloadlist[958:]):
  trying_index=i+958
  r = requests.get(k[0])
  if r.status_code == 200:
    print(trying_index,":","successful")
    img_data = r.content
    with open(f'/content/drive/MyDrive/Colab Notebooks/image_new/{k[1]}.jpg', 'wb') as handler:
      handler.write(img_data)
  else:
    print(trying_index,":","failed. url:",k[0])
    faileddownload.append((k[0],k[1]))
# Out:
# 958 : successful
# 959 : successful
# 960 : failed. url: https://ipfs.io/ipfs/QmcXr8uCZFN89L4ptNu3BbmApEfc5hximRTegMJgF8W3vG
# 961 : successful
# 962 : successful
# 963 : successful
# 964 : successful
# 965 : failed. url: https://ipfs.io/ipfs/QmTPXRe2K6CgLcWuV8pGFWC2aXe4DMYhCMn7bP3ubJSYyP
# 966 : successful
# 967 : failed. url: https://ipfs.io/ipfs/QmVPimV6DQiAkCyz3z8VuLHHtaongYEQCupAJJu5KirFvz
# 968 : successful
# 969 : failed. url: https://ipfs.io/ipfs/QmQ45UQ19Sj4gxgrutnCQSPGYPpVravrexDmyf6Bpchngj
# 970 : successful
# 971 : failed. url: https://ipfs.io/ipfs/Qmecnoi5A3o1NPfrTBrWvURYRnbAoEXXwrmsGzTrburuhT
# 972 : failed. url: https://ipfs.io/ipfs/QmezMHZfvZhga2LFwurugEARR1BdeTTkHDtDoXS8Cu18ia
# 973 : failed. url: https://ipfs.io/ipfs/QmahJWNEqRMpcooSZp5CJxUSauTBtS1aS4nMCZie6Pr3SY
# 974 : successful
# 975 : successful
# 976 : successful
# 977 : successful
# 978 : successful
# 979 : successful
# 980 : successful
# 981 : successful
# 982 : successful
# 983 : successful
# ...

# %%
len(faileddownload)
# Out:
# 45

# %%
trying_index
# Out:
# 1569

# %%
os.chdir('D:\capstone')

# %%
def downloadimage(start):
  for i,k in enumerate(downloadlist[start:]):
    trying_index=i+start
    r = requests.get(k[0])
    if r.status_code == 200:
      print(trying_index,":","successful")
      img_data = r.content
      with open(f'image_new on 5feb/{k[1]}.jpg', 'wb') as handler:
        handler.write(img_data)
    else:
      print(trying_index,":","failed. url:",k[0])
      faileddownload.append((k[0],k[1]))
  return

# %%
downloadimage(trying_index)
# Out:
# 1569 : successful
# 1570 : successful
# 1571 : successful
# 1572 : successful
# 1573 : successful
# 1574 : successful
# 1575 : successful
# 1576 : successful
# 1577 : successful
# 1578 : successful
# 1579 : successful
# 1580 : successful
# 1581 : successful
# 1582 : successful
# 1583 : successful
# 1584 : successful
# 1585 : successful
# 1586 : successful
# 1587 : successful
# 1588 : successful
# 1589 : successful
# 1590 : successful
# 1591 : successful
# 1592 : successful
# 1593 : successful
# 1594 : successful
# 1595 : successful
# 1596 : successful
# 1597 : successful
# 1598 : successful
# 1599 : successful
# 1600 : successful
# 1601 : successful
# 1602 : successful
# 1603 : successful
# 1604 : successful
# 1605 : successful
# 1606 : successful
# 1607 : successful
# 1608 : successful
# 1609 : successful
# 1610 : successful
# 1611 : successful
# 1612 : successful
# 1613 : successful
# 1614 : successful
# 1615 : successful
# 1616 : successful
# 1617 : successful
# 1618 : successful
# ...

# %%
trying_index=2137

# %%
downloadimage(trying_index)
# Out:
# 2137 : successful
# 2138 : successful
# 2139 : successful
# 2140 : successful
# 2141 : successful
# 2142 : successful
# 2143 : successful
# 2144 : successful
# 2145 : successful
# 2146 : successful
# 2147 : successful
# 2148 : successful
# 2149 : successful
# 2150 : successful
# 2151 : successful
# 2152 : successful
# 2153 : successful
# 2154 : successful
# 2155 : successful
# 2156 : successful
# 2157 : successful
# 2158 : successful
# 2159 : successful
# 2160 : successful
# 2161 : successful
# 2162 : successful
# 2163 : successful
# 2164 : successful
# 2165 : successful
# 2166 : successful
# 2167 : successful
# 2168 : successful
# 2169 : successful
# 2170 : successful
# 2171 : successful
# 2172 : successful
# 2173 : successful
# 2174 : successful
# 2175 : successful
# 2176 : successful
# 2177 : successful
# 2178 : successful
# 2179 : successful
# 2180 : successful
# 2181 : successful
# 2182 : successful
# 2183 : successful
# 2184 : successful
# 2185 : successful
# 2186 : successful
# ...

# %%
faileddownload=[]
downloadimage(20052)
# Out:
# 20052 : successful
# 20053 : successful
# 20054 : successful
# 20055 : successful
# 20056 : failed. url: https://ipfs.io/ipfs/QmRKKgiLk1nUjwUAyJQXTgna9Pf4hH2JbfN7tfzPSoELZr
# 20057 : failed. url: https://ipfs.io/ipfs/QmfSKEnJ7P5XV4gSyk9vtsxiwH5pqg4bPHFAZnQPjqZQGp
# 20058 : successful
# 20059 : successful
# 20060 : successful
# 20061 : successful
# 20062 : failed. url: https://ipfs.io/ipfs/QmbSW3xBJeq7xDNLxbmagAb6mMPttBBL7f8kmCTDRMswRo
# 20063 : successful
# 20064 : successful
# 20065 : successful
# 20066 : successful
# 20067 : successful
# 20068 : successful
# 20069 : successful
# 20070 : successful
# 20071 : successful
# 20072 : successful
# 20073 : successful
# 20074 : successful
# 20075 : successful
# 20076 : successful
# 20077 : failed. url: https://ipfs.io/ipfs/QmTa4CXiQJjUNL3S2cgRYzrY9vyxawzjWrQvxM5FHWKrTh
# 20078 : successful
# 20079 : successful
# 20080 : successful
# 20081 : successful
# 20082 : successful
# 20083 : successful
# 20084 : successful
# 20085 : successful
# ...

# %%
downloadimage(27044)
# Out:
# 27044 : successful
# 27045 : successful
# 27046 : successful
# 27047 : successful
# 27048 : successful
# 27049 : successful
# 27050 : successful
# 27051 : successful
# 27052 : successful
# 27053 : successful
# 27054 : successful
# 27055 : successful
# 27056 : successful
# 27057 : successful
# 27058 : successful
# 27059 : successful
# 27060 : successful
# 27061 : successful
# 27062 : successful
# 27063 : successful
# 27064 : successful
# 27065 : successful
# 27066 : successful
# 27067 : successful
# 27068 : successful
# 27069 : successful
# 27070 : successful
# 27071 : successful
# 27072 : successful
# 27073 : failed. url: https://ipfs.io/ipfs/QmSx6Lz59dkrKoXBRdUz1voBTrniQXPY5MSgcQyF8cEBSb
# 27074 : successful
# 27075 : successful
# 27076 : successful
# 27077 : successful
# 27078 : successful
# 27079 : successful
# 27080 : successful
# 27081 : successful
# 27082 : successful
# 27083 : successful
# 27084 : successful
# 27085 : successful
# 27086 : successful
# 27087 : successful
# ...

# %%
downloadimage(90000)
# Out:
# 90000 : successful
# 90001 : successful
# 90002 : successful
# 90003 : successful
# 90004 : successful
# 90005 : successful
# 90006 : successful
# 90007 : successful
# 90008 : successful
# 90009 : successful
# 90010 : successful
# 90011 : successful
# 90012 : successful
# 90013 : successful
# 90014 : successful
# 90015 : successful
# 90016 : successful
# 90017 : successful
# 90018 : successful
# 90019 : successful
# 90020 : successful
# 90021 : successful
# 90022 : successful
# 90023 : successful
# 90024 : successful
# 90025 : successful
# 90026 : successful
# 90027 : successful
# 90028 : successful
# 90029 : successful
# 90030 : successful
# 90031 : successful
# 90032 : successful
# 90033 : successful
# 90034 : successful
# 90035 : successful
# 90036 : successful
# 90037 : successful
# 90038 : successful
# 90039 : successful
# 90040 : successful
# 90041 : successful
# 90042 : successful
# 90043 : successful
# 90044 : successful
# 90045 : successful
# 90046 : successful
# ...

# %%
faileddownload=[]
downloadimage(90074)
# Out:
# 90074 : successful
# 90075 : successful
# 90076 : successful
# 90077 : successful
# 90078 : successful
# 90079 : successful
# 90080 : successful
# 90081 : successful
# 90082 : successful
# 90083 : failed. url: https://ipfs.io/ipfs/QmfTFBUmVWVoA4KXPwyMeW6dUVQVHk18Nt7qgxrHXV4jjK
# 90084 : successful
# 90085 : failed. url: https://ipfs.io/ipfs/QmPWj66X87A8HEg3sj9L3aTG5exgedxa4ySdtq2eFwH56m
# 90086 : successful
# 90087 : successful
# 90088 : successful
# 90089 : successful
# 90090 : successful
# 90091 : successful
# 90092 : successful
# 90093 : successful
# 90094 : successful
# 90095 : successful
# 90096 : successful
# 90097 : successful
# 90098 : successful
# 90099 : successful
# 90100 : successful
# 90101 : successful
# 90102 : successful
# 90103 : successful
# 90104 : successful
# 90105 : successful
# 90106 : successful
# 90107 : successful
# 90108 : successful
# 90109 : successful
# 90110 : successful
# 90111 : successful
# 90112 : successful
# 90113 : successful
# ...

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)

# %%
downloadimage(trying_index)
